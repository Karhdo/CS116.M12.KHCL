# %% [markdown]
# <h1 align="center"><b>Tutorial Matplotlib</h1></b>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# #Introduction to Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available # list ra những style có trong matplotlib
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-whitegrid')

# %%
plt.plot();

# %%
x = [1, 2, 3, 4]
y = [10, 8, 6, 9]

plt.plot(x, y); #Vẽ đồ thị theo x và y

# %% [markdown]
# #Pyplot API vs Oriented API
# - Pyplot API -> Quicky
# - Oriented API -> Advanced

# %% [markdown]
# ##Pyplot API -> Quicky

# %%
x = np.linspace(0, 10, 1000) #x từ 0 -> 10 và gồm 1000 dữ liệu x
plt.plot(x, np.sin(x), color='blue', linestyle='dashed', label='sin(x)');
plt.plot(x, np.cos(x), color='red', label='cos(x)');

plt.title('sin(x) and cos(x)')
plt.xlabel('x'); #Label cho trục Ox, Oy
plt.ylabel('F(x)');

#Giới hạn độ dài của trục Ox và Oy
#plt.xlim([0, 8]) 
#plt.ylim([-1, 0.75])
#plt.axis(xmin, xmax, ymin, ymax)
plt.axis("equal")

plt.legend(); #Dùng để hiện label trên đồ thị.

# %% [markdown]
# ##Oriented API

# %%
#1 Prepare data
x = [1,2,3,4]
y = [11,22,33,44]

#2 Setup plot
fig, ax = plt.subplots(figsize=(5,5)) #Figure size = width and height of the plot

#3 Plot data
ax.plot(x, y);
ax.set(title='Simple plot',
       xlabel='x-axis',
       ylabel='y-axis');

# %% [markdown]
# #Most common types of Matplotlib Plot
# - line
# - scatter
# - bar
# - hit
# - subplots()

# %%
#Create an array
x = np.linspace(0, 10, 100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
#OO API plot line chart
fig, ax = plt.subplots()
ax.plot(x, x**3)

# %% [markdown]
# ##Scatter (Biểu đồ phân tán)

# %%
#Pylot API
plt.scatter(x, np.exp(x))

# %%
#OO API

#Prepare new data
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)

colors = rng.rand(100)
size = 1000*rng.rand(100)

fig, ax = plt.subplots()

plot_1 = ax.scatter(x, y, s=size, c=colors, cmap='viridis', alpha=0.3); #cmap: chỉnh theme màu, alpha: chỉnh độ trong suốt của màu

fig.colorbar(plot_1);

# %% [markdown]
# ##Bar chart
# - Vertical
# - Horizontal

# %%
# Prepare Data
soft_drink_prices = {'CoaCoLa':10, 'Pesi': 12, 'Sprite': 8} 

fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values())

ax.set(title='Soft drink prices', xlabel='Name', ylabel='Prices ($)');

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ##Histogram

# %%
#Prepare data
np.random.seed(42) #Dùng để random lần nào cũng ra giống nhau
student_height = np.random.normal(170, 10, 250) # (giá trị trung bình, độ lệch chuẩn, số lượng)
student_height[:10]
# Out:
# array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#        167.65846625, 167.65863043, 185.79212816, 177.67434729,
#        165.30525614, 175.42560044])

# %%
#pylot API
plt.hist(student_height, bins=30); #bins dùng để chia nhỏ dữ liệu

# %% [markdown]
# #Subplots

# %%
# Option 1: 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5))
#Plot data to each axis
ax1.plot(x, x/2);
ax1.plot(x, x*2);

ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax4.hist(student_height, bins=30);

# %%
# Option 2:
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10,5))
#Plot data to each axis
ax[0,0].plot(x, x/2);
ax[0,0].plot(x, x*2);

ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax[1,1].hist(student_height, bins=30);

# %% [markdown]
# <h1 align="center"><b>Project: Data Visual California Cities</h1></b>

# %%
cities = pd.read_csv('/gdrive/MyDrive/Colab Notebooks/Lập trình Python cho Máy học/Week 1/Data/california_cities.csv')
cities.head()
# Out:
#    Unnamed: 0         city  ...  area_water_km2  area_water_percent
# 0           0     Adelanto  ...           0.046                0.03
# 1           1  AgouraHills  ...           0.076                0.37
# 2           2      Alameda  ...          31.983               53.79
# 3           3       Albany  ...           9.524               67.28
# 4           4     Alhambra  ...           0.003                0.01
#
# [5 rows x 14 columns]

# %% [markdown]
# - latd(line of latitude): Kinh độ
# - longd(line of longitude): Vĩ độ => Điểm giao nhau giữa kinh độ và vĩ độ là bị trị của thành phố
# - population_total: số dân số của dân số
# - area_total_sq_mi: diện tích của thành phố

# %%
cities['area_total_km2'].sort_values(ascending=False)
# Out:
# 239    1302.000
# 367     964.510
# 55      527.401
# 375     466.109
# 26      371.946
#          ...
# 163         NaN
# 237         NaN
# 370         NaN
# 393         NaN
# 443         NaN
# Name: area_total_km2, Length: 482, dtype: float64

# %%
#Extract latd and longd
lat, log = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

plt.figure(figsize=(10,8))
#Plot using Pyplot API
plt.scatter(log, lat,
            c=np.log10(population), 
            cmap='viridis',
            s=area,
            linewidths=0,
            alpha=0.5);
plt.axis('equal');
plt.title('California Cities: Pouplation and Area Distribution')
plt.xlabel('line of longitude');
plt.ylabel('line of latitude');

plt.colorbar(label='log$_{10}$(population)');
plt.clim(3,7);

#Create legend for Cities'sizes
area_range = [50, 100, 300, 500]

for area in area_range:
  plt.scatter([], [], 
              s=area, 
              c='k', 
              alpha=0.5,
              label=str(area) + 'km$^2$')

plt.legend(labelspacing=1, title='Cities Area');
